# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import gmaps
import os
from config import g_key

# %%
print(g_key)
# Out:
# AIzaSyDEyq_cqyyZtooMHdAd6kYJhEWHKronlaw

# %%
#AIzaSyDXDirfdpVRzU9rKbmscZKwU8_xAjCaOqY

# %%
# Specify the URL
#Resouces search = https://developers.google.com/places/web-service/overview
target_url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query=123+main+street&location=42.3675294,-71.186966&radius=10000&key={g_key}"

# %%
print (target_url)
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=123+main+street&location=42.3675294,-71.186966&radius=10000&key=AIzaSyDEyq_cqyyZtooMHdAd6kYJhEWHKronlaw

# %%
# Make request and store response
response = requests.get(target_url)

# Print status code
print(response.status_code)
# Out:
# 200

# %%
# Build query URL
##query_url = target_url + "apid=" + g_key + "&q="
#query_url

# %%
 # JSON's response
 # Get Vacationpy data
Vacationpy_response = requests.get(target_url)
Vacationpy_json = Vacationpy_response.json()

# %%
# Print the json
#VacationPy
print (Vacationpy_response.json())
# Out:
# {'html_attributions': [], 'next_page_token': 'ATtYBwKwZIV5K9CMQIG_fV2epX9CDEyg0EyL15J-nZtbOCWK1Wyjzr2NWTQQc-Cp5xbwptPxBB1CcnsUj642Y5-z9ETQNtNUsd2uWjNv72vGyPyGh2uwsNmHEu_2S4AXlpC1c29Zsg0EZ7EndjAk1ioIVEI6-lYnkDop0_SFqHzjQTj6d484Qoek5slKJl1EDaP-ma5uMU2dYjUnX3h9jaXmEUt2gzar5UMJBZ5N2jbZ0K3h84yHrhv3ELTdfIGbK8lp8yblKkspBJbpM6pfTGO5IsdzfxWJpWKp4ASv9exkZdUFiohu16ytMM63rR5COOGhcTmBmAcrgQsuATHekU3m7wr5Vd37fZ49cXcSkN5AdaUrg_we_piVxGT6MwcC2yoaCIkNRF2qIplo9hbIr3WDF33QuxMcPwWzpWG1AeiJ88ORkQ1kSVAcohzviCL1EW-1TUdbSbYMbA', 'results': [{'business_status': 'OPERATIONAL', 'formatted_address': '123 Main St, Watertown, MA 02472, United States', 'geometry': {'location': {'lat': 42.36752910000001, 'lng': -71.1868318}, 'viewport': {'northeast': {'lat': 42.36897462989272, 'lng': -71.18531467010727}, 'southwest': {'lat': 42.36627497010728, 'lng': -71.18801432989272}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png', 'name': 'Watertown Free Public Library', 'opening_hours': {
# ...

# %%
 # Pretty Print the output of the JSON
 #print (Vacationpy_response.json())
 #response = requests.get(target_url)
response = requests.get(target_url).json()
#print(json.dumps(response, indent=4, sort_keys=True))
type(response)
# Out:
# dict

# %%
response = requests.get(target_url).json()
geo_data = response

# %%
print(target_url)
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=123+main+street&location=42.3675294,-71.186966&radius=10000&key=AIzaSyDEyq_cqyyZtooMHdAd6kYJhEWHKronlaw

# %%
response = requests.get(target_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwKCe7H2rZ2ZbTm06xn8scqGE85zKkW1pg4yNWvW3FYkOtH4piCWGVM6FGHcZU6SRWoU8LcK2N6lplJbbWECo3najp_jxC54Ey6y5BCX5zk9Pfj7chqWurLG8eFKloVZsiY1dp5xkk2Sh9N1d_FXrcReRr7dvBlsUoFyhN1xKblakDqw_YORaR3K9EoZiiP-I481WVOys70VEtBx65MkYnjhXU_PXg6fD7BdbQSo3RjEUhgQS-fTt0Gz1U8I1c1SX0XQoA5BSJR9b91f3h6QR8jc3BuMi3KkTO67CxPwjvid5_61_r0p3H1-WHX-BRzVkY1CAw2oJaDP9gRbhMjc9LQ6HDLMbDkobN3woq0whF8ag5AWQFY-yfR86DB0rc15mfL08ZqDwE9WhUVaVj99VJTiwW_AzGrSD4j209WmL8F2We_2RBijziwmfkN0RkefmZCkK4ZDrw",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "formatted_address": "123 Main St, Watertown, MA 02472, United States",
#             "geometry": {
#                 "location": {
#                     "lat": 42.36752910000001,
#                     "lng": -71.1868318
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 42.36897462989272,
# ...

# %%
geo_data = requests.get(target_url).json()

# Print the json
geo_data
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwLeeyeLytW50g6-LXwDSDUP1wcQeW-b2fyhhubQh7lQ8_M2MJIPzprLtS4pJzV3V1D-uHaTrglLaThjLia6iRFY_4ggRZpDUtTKe5n1BrcAZxCGt1Ga_qOo1F8tYRIS_wE0lfFETrssIT4_bwOM9jznNZarrP6ZD2wNftENwpIrDjwXYuvNeVQak9-8TXINqzyLTzgsT0mqJy_iGZl0rb9Mcsoa0ZS-39WvLGyfiIICbAZ9g2izMsne4tC3hMFMY0Zwt1w7VU8ESPd8wYY72UcuwUAQIyJ-OLzPdexxj3Cpsx5Hzh-Ck8BNip6NqckwpSnBNYHnZDXtwlIPakKGDulKRqsxvS4YSkM7URrVd_pGazAjP7z6aqQ45jLA6-jECFzyJdhtoWVBsXCkYYjGaj9sNofK5hkQ9EMPyWg0mas44FraSc34DwvmC2lGjLagshOy9RjUeg',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '123 Main St, Watertown, MA 02472, United States',
#    'geometry': {'location': {'lat': 42.36752910000001, 'lng': -71.1868318},
#     'viewport': {'northeast': {'lat': 42.36897462989272,
#       'lng': -71.18531467010727},
#      'southwest': {'lat': 42.36627497010728, 'lng': -71.18801432989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
# ...

# %%
#import numpy.ma.mrecords as mrecords
geo_data = pd.DataFrame(geo_data)
geo_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-0dde23528cd2> in <module>
#       1 #import numpy.ma.mrecords as mrecords
# ----> 2 geo_data = pd.DataFrame(geo_data)
#       3 geo_data
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# ...

# %%
 # Print the json (pretty printed)
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwLeeyeLytW50g6-LXwDSDUP1wcQeW-b2fyhhubQh7lQ8_M2MJIPzprLtS4pJzV3V1D-uHaTrglLaThjLia6iRFY_4ggRZpDUtTKe5n1BrcAZxCGt1Ga_qOo1F8tYRIS_wE0lfFETrssIT4_bwOM9jznNZarrP6ZD2wNftENwpIrDjwXYuvNeVQak9-8TXINqzyLTzgsT0mqJy_iGZl0rb9Mcsoa0ZS-39WvLGyfiIICbAZ9g2izMsne4tC3hMFMY0Zwt1w7VU8ESPd8wYY72UcuwUAQIyJ-OLzPdexxj3Cpsx5Hzh-Ck8BNip6NqckwpSnBNYHnZDXtwlIPakKGDulKRqsxvS4YSkM7URrVd_pGazAjP7z6aqQ45jLA6-jECFzyJdhtoWVBsXCkYYjGaj9sNofK5hkQ9EMPyWg0mas44FraSc34DwvmC2lGjLagshOy9RjUeg",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "formatted_address": "123 Main St, Watertown, MA 02472, United States",
#             "geometry": {
#                 "location": {
#                     "lat": 42.36752910000001,
#                     "lng": -71.1868318
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 42.36897462989272,
# ...

# %%
#geo_data_csv_df = pd.read_csv('geo_data.csv')
# Show just the header
#geo_data_csv_df.head()

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Store filepath in a variable
weather_csv = "weather_data.csv"

# %%
# Read Data file with the pandas library
weather_csv_df = pd.read_csv('weather_data.csv')
# Show just the header
weather_csv_df.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, city, lat, temp, humidity, clouds, speed, lon, temp_main, temp_max]
# Index: []

# %%
#IDEAL WEATHER
#A max temperature lower than 80 degrees but higher than 70. temp_max <70; >80
# Wind speed less than 10 mph.
# Zero cloudiness.
# Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.

# %%
weather_csv_df = weather_csv_df.dropna(axis=1)
print(weather_csv_df)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, city, lat, temp, humidity, clouds, speed, lon, temp_main, temp_max]
# Index: []

# %%
location_df = weather_csv_df[["lat" , "lon"]].drop_duplicates()
location_df
# Out:
# Empty DataFrame
# Columns: [lat, lon]
# Index: []

# %%
# Extract latitude and longitude
lat = geo_data["results"][4]["geometry"]["location"]["lat"]
lng = geo_data["results"][9]["geometry"]["location"]["lng"]

# Print the latitude and longitude
print('''
    City: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format("Georgetown", lat, lng))
# Out:
#     City: Georgetown
#     Latitude: 42.4194162
#     Longitude: -71.349673

# %%
# Output File (CSV)
output_data_file = "response"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

#Print(output_data_file)

# %%
## create a data frame from cities, lat, and temp
#weather_dict = {
                "city": city_with_data,
                #"lat": lat,
                #"temp": temp,
                #"humidity":  hum,
                #"clouds":    cloud,
                #"speed": wind,
                #"lon": lon,
                #"temp_main": temp_main,
                #"temp_max": temp_max
#}

#import numpy.ma.mrecords as mrecords
#weather_data = pd.DataFrame(weather_dict)
#weather_data
#print(weather_dict)
# Out:
#   File "<ipython-input-36-7a2673e11c50>", line 3
#     "city": city_with_data,
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#Configure gmaps.
gmaps.configure(api_key=g_key)

# %%
#!conda install -c conda-forge gmaps

# %%
#Use the Lat and Lng as locations and Humidity as the weight.
import gmaps

# Google developer API key
from config import g_key

# Access maps with unique API key
gmaps.configure(api_key=g_key)

# %%
# Create a list containing coordinates
coordinates = [
    (29.5833,-9.5),
    (-22.9661,-42.0278),
    (-51.6226,-69.2181),
    (53.0452,158.6483),
    (62.456,-114.35250),
    (-9.8,-139.0333),
    (77.484,-69.3632),
    (53.45,125.8),
    (-21.2,-175.2),
    (8.7341,76.7067),
    (38.5167,-28.7),
    (27.9769,-114.0611),
    (51.0693,-1.7957),
    (59.7035,30.7861),
    (-42.8794,147.3294),
    (5.4112,100.3354),
    (-37.6167,-73.65),
    (42.5617,-2.356),
    (19.7297,-155.09),
    (-2.5257,40.5262),
    (29.0331,21.5482),  
    (42.6411,-95.2097),
    (5.2767,115.2417),
]

# %%
# Customize the size of the figure
figure_layout = {
    'width': '800px',
    'height': '600px',
    'border': '2px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
# Marker layer assignment to a variable
my_points = gmaps.marker_layer(coordinates)
# Adding the layer to the map
fig.add_layer(my_points)
fig
# Out:
# Figure(layout=FigureLayout(border='2px solid black', height='600px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#IDEAL WEATHER
#A max temperature lower than 80 degrees but higher than 70. temp_max <70; >80
# Wind speed less than 10 mph.
# Zero cloudiness.
# Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.

# %%
weather_csv_df = pd.read_csv('weather_data.csv')
# Show just the header
weather_csv_df.shape
# Out:
# (23, 10)

# %%
narrowed_city_df = weather_csv_df.loc[(weather_csv_df["temp_max"] < 80) & (weather_csv_df["temp_max"] > 70) \
                                     & (weather_csv_df["speed"] < 10) \
                                     & (weather_csv_df["clouds"] == 0)].dropna()
narrowed_city_df.count
# Out:
# <bound method DataFrame.count of Empty DataFrame
# Columns: [Unnamed: 0, city, lat, temp, humidity, clouds, speed, lon, temp_max]
# Index: []>

# %%
# Tiznit Province

# %%
# create a data frame from cities, lat, and temp
# ideal_location_df = {
                # "city": 'Tiznit Province',
                # "lat": lat,
                # "temp": temp,
                # "humidity":  hum,
                # "clouds":    cloud,
                # "speed": wind,
                # "lon": lon,
                # "temp_main": temp_main,
                # "temp_max": temp_max
# }

#import numpy.ma.mrecords as mrecords
# ideal_location_df = pd.DataFrame(ideal_location_df)
# ideal_location_df
#print(weather_dict)

# %%
ideal_location_csv_df = weather_csv_df.loc[(weather_csv_df["temp_max"] < 80) & (weather_csv_df["temp_max"] > 70) \
                                    & (weather_csv_df["speed"] < 10) \
                                    & (weather_csv_df["clouds"] == 0)].dropna()
print(ideal_location_csv_df)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, city, lat, temp, humidity, clouds, speed, lon, temp_max]
# Index: []

# %%
#weather_csv_df
# ideal_location_df = weather_csv_df[["lat" , "lon"]].drop_duplicates()
# ideal_location_df.loc[weather_csv_df['temp_max'] == [70, 80]
# #ideal_location_df.loc[weather_csv_df['speed'] == <=10],
#ideal_location_df.loc[weather_csv_df['clouds'] == <=0]

# %%
#weather_csv_df
# weather_csv_df.loc[(weather_csv_df['temp_max'] >= 70)
# weather_csv_df.loc[(weather_csv_df['temp_max'] <= 80)]
# weather_csv_df.loc[(weather_csv_df['speed'] <= 10)
# weather_csv_df.loc[(weather_csv_df['clouds'] <= 0)

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure

# %%
# # 5. Can ride bumper cars
# height = 66
# age = 16
# adult_permission = True

# if (height > 70) and (age >= 18):
#     print("Can ride all the roller coasters")
# elif (height > 65) and (age >= 18):
#     print("Can ride moderate roller coasters")
# elif (height > 60) and (age >= 18):
#     print("Can ride light roller coasters")
# elif ((height > 50) and (age >= 18)) or ((adult_permission) and (height > 50)):
#     print("Can ride bumper cars")
# else:
#     print("Stick to lazy river")
