# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy import stats
#from config import api_key
from scipy.stats import linregress

# Import API key
#from api_keys import weather_api_key
from config import weather_api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
print (weather_api_key)
# Out:
# 3828483840e7d3f41de4bd10585da72f

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %%
print(cities)
# Out:
# ['fortuna', 'katsuura', 'beisfjord', 'touros', 'hilo', 'bluff', 'santa fe', 'puerto ayora', 'lorengau', 'mar del plata', 'saint-francois', 'predivinsk', 'qaanaaq', 'grindavik', 'nikolskoye', 'woodland', 'nehe', 'agdam', 'arraial do cabo', 'new norfolk', 'tortoli', 'araguacu', 'tsihombe', 'cayenne', 'codrington', 'porto novo', 'port lincoln', 'kruisfontein', 'rikitea', 'kassala', 'gushikawa', 'albany', 'yellowknife', 'abu kamal', 'barentsburg', 'port alfred', 'lebu', 'sheridan', 'souillac', 'port hardy', 'ishigaki', 'tuktoyaktuk', 'vestmannaeyjar', 'vaitupu', 'upernavik', 'busselton', 'agadez', 'ushuaia', 'illoqqortoormiut', 'dunedin', 'port elizabeth', 'bima', 'barrow', 'vila velha', 'laguna', 'mount gambier', 'channel-port aux basques', 'artyk', 'hay river', 'mayo', 'prince rupert', 'korla', 'luderitz', 'terra rica', 'saint anthony', 'baldeogarh', 'guerrero negro', 'mackay', 'florence', 'lavrentiya', 'sorrento', 'cherskiy', 'longyearbyen', 'butaritari', 'raga', 'potam', 'rawannawi', 'seddon', 'portel', 'mango', 'daru', 'vagay', 'carutapera', 'kulhudhuffushi', 'atuona', 'moroto', 'east london', 'manzil tamim', 'georgetown', 'hofn', 'talnakh', 'road town', 'hobart', 'castro', 'san cristobal', 'sibu', 'chokurdakh', 'kiunga', 'ixtapa', 'necochea', 'wakkanai', 'beruni', 'meulaboh', 'hella', 'rocha', 'krasnokamensk', 'pevek', 'pestravka', 'tafo', 'matara', 'ahipara', 'bengkulu', 'tome-acu', 'portland', 'palabuhanratu', 'vaini', 'juneau', 'tilichiki', 'saskylakh', 'mataura', 'saint-philippe', 'okhotsk', 'punta arenas', 'kattivakkam', 'jurbarkas', 'graciano sanchez', 'saldanha', 'capelinha', 'ormara', 'viligili', 'menongue', 'cortez', 'haines junction', 'cabra', 'inhambane', 'cazaje', 'bandiagara', 'taolanaro', 'killybegs', 'goderich', 'hithadhoo', 'tacoronte', 'soria', 'faanui', 'los llanos de aridane', 'ucluelet', 'hermanus', 'kavaratti', 'magistralnyy', 'micheweni', 'kodiak', 'san ramon', 'cermik', 'lompoc', 'ilulissat', 'sentyabrskiy', 'deputatskiy', 'ust-omchug', 'tiksi', 'sao filipe', 'cape town', 'louisbourg', 'qui nhon', 'basoko', 'saint-pierre', 'mahebourg', 'thompson', 'hualmay', 'machali', 'tual', 'egvekinot', 'puerto penasco', 'bur gabo', 'taltal', 'kuala krai', 'broome', 'hamilton', 'tartagal', 'avarua', 'murdochville', 'auki', 'salekhard', 'attawapiskat', 'dingle', 'xinxiang', 'tasiilaq', 'ponta do sol', 'ancud', 'saint-augustin', 'chuy', 'amderma', 'hobyo', 'jamestown', 'liminangcong', 'okuchi', 'carnarvon', 'pisco', 'roald', 'anori', 'bredasdorp', 'yamada', 'great falls', 'hambantota', 'evensk', 'broken hill', 'yerbogachen', 'darnah', 'brejo da madre de deus', 'college', 'grand river south east', 'mys shmidta', 'port blair', 'shchelyayur', 'les escoumins', 'tumannyy', 'longlac', 'klaksvik', 'kez', 'san patricio', 'tabanan', 'henties bay', 'lomovka', 'sterling', 'diffa', 'dikson', 'alice springs', 'kunnamangalam', 'springbok', 'isangel', 'sambava', 'meyungs', 'fengxian', 'biloela', 'port-louis', 'sharkan', 'cidreira', 'esil', 'sinnamary', 'ust-nera', 'kenai', 'moron', 'husavik', 'kapaa', 'valparaiso', 'ardistan', 'severo-kurilsk', 'san quintin', 'haibowan', 'vao', 'almansa', 'cap malheureux', 'yulara', 'airai', 'phek', 'pangnirtung', 'pryozerne', 'tasbuget', 'sistranda', 'waipawa', 'xiaoweizhai', 'matay', 'nantucket', 'sarkand', 'roebourne', 'trelew', 'comodoro rivadavia', 'odweyne', 'coquimbo', 'luena', 'vredendal', 'payson', 'seymchan', 'khatanga', 'kaitangata', 'shimoda', 'lima', 'kharp', 'victoria', 'iqaluit', 'wangqing', 'ayagoz', 'hovd', 'eyl', 'tanete', 'tabou', 'bembereke', 'temaraia', 'provideniya', 'camacha', 'montijo', 'kahului', 'khovu-aksy', 'nemuro', 'sabang', 'shetpe', 'lincoln', 'leningradskiy', 'aksarka', 'alekseyevsk', 'abu jubayhah', 'kamenskoye', 'novoagansk', 'hasaki', 'lagoa', 'toliary', 'jumla', 'srednekolymsk', 'mehamn', 'bella union', 'san andres', 'houma', 'ribeira grande', 'cabo san lucas', 'teguise', 'fort nelson', 'amga', 'bambous virieux', 'esperance', 'tecoanapa', 'aklavik', 'sozimskiy',  ...

# %%
url = "http://api.worldbank.org/v2/"
api_format = "json"

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
api_format = "json"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
print (url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?

# %%
print (query_url+'cities')
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=3828483840e7d3f41de4bd10585da72f&units=metric&q=cities

# %%
cities = ['angkat', 'illoqqortoormiut', 'tiznit', 'arraial do cabo', 'rio gallegos', 'petropavlovsk-kamchatskiy', 'yellowknife', 'atuona', 'qaanaaq', 'magdagachi', 'vaini', 'varkkallai', 'ribeira grande', 'guerrero negro', 'salisbury', 'nikolskoye', 'hobart', 'georgetown', 'lebu', 'aras', 'hilo', 'kipini', 'jalu', 'storm lake', 'labuan']
# set up lists to hold reponse info
lat = []
temp = []
city_with_data = []

# %%
print (cities[0])
print (cities [-1])
# Out:
# angkat
# labuan

# %%
#try:
    #print(jffjj)
#except:
    #print("the line is error")

# %%
lat.append("Chennaiu")
print(lat)
# Out:
# ['Chennaiu']

# %%
lat.append("US")
print(lat)
# Out:
# ['Chennaiu', 'US']

# %%
response = requests.get(query_url + "city").json()
#response['main']['pressure']
#response ['wind']['deg']

#response['clouds']
#response['clouds']['all']
response
# Out:
# {'coord': {'lon': 149.1292, 'lat': -35.2813},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 10.55,
#   'feels_like': 7.01,
#   'temp_min': 10,
#   'temp_max': 11,
#   'pressure': 1019,
#   'humidity': 71},
#  'visibility': 10000,
#  'wind': {'speed': 3.6, 'deg': 140},
#  'clouds': {'all': 90},
#  'dt': 1614096378,
#  'sys': {'type': 1,
#   'id': 9588,
#   'country': 'AU',
#   'sunrise': 1614109527,
#   'sunset': 1614156503},
#  'timezone': 39600,
#  'id': 2172517,
#  'name': 'City',
#  'cod': 200}

# %%
# Loop through the list of cities and perform a request for data on each
lat= []
temp = []
hum = []
cloud = []
wind = []
lon = []
temp_main = []
temp_max = []

city_with_data = []
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        city_with_data.append(response['name'])
        hum.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        lon.append(response['coord']['lon'])
        temp_main.append(response['main'].get('temp_main', None))
        temp_max.append(response['main'].get('temp_max', None))
       
    except Exception as e:
        print(f"The information {city} is missing")
        print(e)
# Out:
# The information angkat is missing
# 'coord'
# The information illoqqortoormiut is missing
# 'coord'

# %%
print(city_with_data)
# Out:
# ['Tiznit Province', 'Arraial do Cabo', 'Río Gallegos', 'Petropavlovsk-Kamchatskiy', 'Yellowknife', 'Atuona', 'Qaanaaq', 'Magdagachi', 'Vaini', 'Varkala', 'Ribeira Grande', 'Guerrero Negro', 'Salisbury', 'Nikolskoye', 'Hobart', 'George Town', 'Lebu', 'Aras', 'Hilo', 'Kipini', 'Jalu', 'Storm Lake', 'Labuan']

# %%
print(f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
# Out:
# The latitude information received is: [29.5833, -22.9661, -51.6226, 53.0452, 62.456, -9.8, 77.484, 53.45, -21.2, 8.7341, 38.5167, 27.9769, 51.0693, 59.7035, -42.8794, 5.4112, -37.6167, 42.5617, 19.7297, -2.5257, 29.0331, 42.6411, 5.2767]
# The temperature information received is: [20.37, 29.86, 13, -3, -31.84, 25.85, -13.99, -29.55, 25, 30, 13, 18.61, 11.31, -13.41, 8.66, 28.3, 16.4, 15, 18.17, 26.22, 18.16, 1.19, 25]

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
                "city": city_with_data,
                "lat": lat,
                "temp": temp,
                "humidity":  hum,
                "clouds":    cloud,
                "speed": wind,
                "lon": lon,
                "temp_main": temp_main,
                "temp_max": temp_max
}

#import numpy.ma.mrecords as mrecords
weather_data = pd.DataFrame(weather_dict)
weather_data
#print(weather_dict)
# Out:
#                          city      lat   temp  humidity  clouds  speed  \
# 0             Tiznit Province  29.5833  20.37        36       0   3.77
# 1             Arraial do Cabo -22.9661  29.86        70      20   6.17
# 2                Río Gallegos -51.6226  13.00        41       0   6.69
# 3   Petropavlovsk-Kamchatskiy  53.0452  -3.00        74      75   2.00
# 4                 Yellowknife  62.4560 -31.84        75      20   1.57
# 5                      Atuona  -9.8000  25.85        78      31   5.90
# 6                     Qaanaaq  77.4840 -13.99        61     100   1.99
# 7                  Magdagachi  53.4500 -29.55        84      16   1.89
# 8                       Vaini -21.2000  25.00        83      20   2.57
# 9                     Varkala   8.7341  30.00        70      40   0.42
# 10             Ribeira Grande  38.5167  13.00        58      40   9.26
# 11             Guerrero Negro  27.9769  18.61        31       0   0.61
# 12                  Salisbury  51.0693  11.31        82      40   9.77
# 13                 Nikolskoye  59.7035 -13.41        85      90   7.00
# 14                     Hobart -42.8794   8.66        71      61   4.12
# 15                George Town   5.4112  28.30        65      20   3.60
# 16                       Lebu -37.6167  16.40        64       0  10.11
# 17                       Aras  42.5617  15.00        55      20   6.69
# 18                       Hilo  19.7297  18.17        82      90   2.06
# 19                     Kipini  -2.5257  26.22        81      98   8.15
# 20                       Jalu  29.0331  18.16        33       0   4.50
# 21                 Storm Lake  42.6411   1.19       100       1   3.60
# 22                     Labuan   5.2767  25.00        94      20   1.43
#
#          lon temp_main  temp_max
# 0    -9.5000      None     20.37
# 1   -42.0278      None     31.00
# 2   -69.2181      None     13.00
# 3   158.6483      None     -3.00
# 4  -114.3525      None    -31.67
# 5  -139.0333      None     25.85
# 6   -69.3632      None    -13.99
# 7   125.8000      None    -29.55
# 8  -175.2000      None     25.00
# 9    76.7067      None     30.00
# 10  -28.7000      None     13.00
# 11 -114.0611      None     18.61
# 12   -1.7957      None     12.22
# 13   30.7861      None    -12.78
# 14  147.3294      None     10.00
# 15  100.3354      None     29.00
# 16  -73.6500      None     16.40
# 17   -2.3560      None     15.00
# 18 -155.0900      None     19.00
# 19   40.5262      None     26.22
# 20   21.5482      None     18.16
# 21  -95.2097      None      2.22
# 22  115.2417      None     25.00

# %%
#Convert Raw Data to DataFrame
#Export the city data into a .csv.
#Display the DataFrame

# %%
#Convert Raw Data to DataFrame
# importing the module 
#import pandas as pd 
  
# saving the DataFrame as a CSV file 
weather_data.to_csv('weather_data.csv', index = True) 
print(weather_data.to_csv)
# Out:
# <bound method NDFrame.to_csv of                          city      lat   temp  humidity  clouds  speed  \
# 0             Tiznit Province  29.5833  20.37        36       0   3.77
# 1             Arraial do Cabo -22.9661  29.86        70      20   6.17
# 2                Río Gallegos -51.6226  13.00        41       0   6.69
# 3   Petropavlovsk-Kamchatskiy  53.0452  -3.00        74      75   2.00
# 4                 Yellowknife  62.4560 -31.84        75      20   1.57
# 5                      Atuona  -9.8000  25.85        78      31   5.90
# 6                     Qaanaaq  77.4840 -13.99        61     100   1.99
# 7                  Magdagachi  53.4500 -29.55        84      16   1.89
# 8                       Vaini -21.2000  25.00        83      20   2.57
# 9                     Varkala   8.7341  30.00        70      40   0.42
# 10             Ribeira Grande  38.5167  13.00        58      40   9.26
# 11             Guerrero Negro  27.9769  18.61        31       0   0.61
# 12                  Salisbury  51.0693  11.31        82      40   9.77
# 13                 Nikolskoye  59.7035 -13.41        85      90   7.00
# 14                     Hobart -42.8794   8.66        71      61   4.12
# 15                George Town   5.4112  28.30        65      20   3.60
# 16                       Lebu -37.6167  16.40        64       0  10.11
# 17                       Aras  42.5617  15.00        55      20   6.69
# 18                       Hilo  19.7297  18.17        82      90   2.06
# 19                     Kipini  -2.5257  26.22        81      98   8.15
# 20                       Jalu  29.0331  18.16        33       0   4.50
# 21                 Storm Lake  42.6411   1.19       100       1   3.60
# 22                     Labuan   5.2767  25.00        94      20   1.43
#
#          lon temp_main  temp_max
# 0    -9.5000      None     20.37
# 1   -42.0278      None     31.00
# 2   -69.2181      None     13.00
# 3   158.6483      None     -3.00
# 4  -114.3525      None    -31.67
# 5  -139.0333      None     25.85
# 6   -69.3632      None    -13.99
# 7   125.8000      None    -29.55
# 8  -175.2000      None     25.00
# 9    76.7067      None     30.00
# 10  -28.7000      None     13.00
# 11 -114.0611      None     18.61
# 12   -1.7957      None     12.22
# 13   30.7861      None    -12.78
# 14  147.3294      None     10.00
# 15  100.3354      None     29.00
# 16  -73.6500      None     16.40
# 17   -2.3560      None     15.00
# 18 -155.0900      None     19.00
# 19   40.5262      None     26.22
# 20   21.5482      None     18.16
# 21  -95.2097      None      2.22
# 22  115.2417      None     25.00  >

# %%
#Inspect the data and remove the cities where the humidity > 100%.
#Skip this step if there are no cities that have humidity > 100%.

# %%
#Plotting the Data
#Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#Save the plotted figures as .pngs.

# %%
 # Create a Scatter Plot for temperature vs latitude
x_values = weather_data['lat']
y_values = weather_data['temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.show()
plt.savefig("foo.png", bbox_inches='tight')

# %%
 # Create a Scatter Plot for humidity (%) vs. Latitude
x_values = weather_data['lat']
y_values = weather_data['humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('humidity')
plt.show()
plt.savefig("foo.png", bbox_inches='tight')

# %%
#Cloudiness (%) vs. Latitude
 # Create a Scatter Plot for Cloudiness (%) vs. Latitude
x_values = weather_data['lat']
y_values = weather_data['clouds']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('clouds')
plt.show()
plt.savefig("foo.png", bbox_inches='tight')

# %%
 # Create a Scatter Plot for Wind speed vs. Latitude
x_values = weather_data['lat']
y_values = weather_data['speed']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind speed')
plt.show()
plt.savefig("foo.png", bbox_inches='tight')

# %%
#weather_data["lat_sign"] = np.sign(weather_data.lat)
#print(weather_data).lat_sign

# %%
# create a data frame from cities, lat, and temp
North_dict = {
                "city": city_with_data,
                "lat": lat,
                "temp": temp,
                "humidity":  hum,
                "clouds":    cloud,
                "speed": wind,
                "lon": lon,
                "temp_max": temp_max
}
North_dict = pd.DataFrame(North_dict)
North_dict
# Out:
#                          city      lat   temp  humidity  clouds  speed  \
# 0             Tiznit Province  29.5833  20.37        36       0   3.77
# 1             Arraial do Cabo -22.9661  29.86        70      20   6.17
# 2                Río Gallegos -51.6226  13.00        41       0   6.69
# 3   Petropavlovsk-Kamchatskiy  53.0452  -3.00        74      75   2.00
# 4                 Yellowknife  62.4560 -31.84        75      20   1.57
# 5                      Atuona  -9.8000  25.85        78      31   5.90
# 6                     Qaanaaq  77.4840 -13.99        61     100   1.99
# 7                  Magdagachi  53.4500 -29.55        84      16   1.89
# 8                       Vaini -21.2000  25.00        83      20   2.57
# 9                     Varkala   8.7341  30.00        70      40   0.42
# 10             Ribeira Grande  38.5167  13.00        58      40   9.26
# 11             Guerrero Negro  27.9769  18.61        31       0   0.61
# 12                  Salisbury  51.0693  11.31        82      40   9.77
# 13                 Nikolskoye  59.7035 -13.41        85      90   7.00
# 14                     Hobart -42.8794   8.66        71      61   4.12
# 15                George Town   5.4112  28.30        65      20   3.60
# 16                       Lebu -37.6167  16.40        64       0  10.11
# 17                       Aras  42.5617  15.00        55      20   6.69
# 18                       Hilo  19.7297  18.17        82      90   2.06
# 19                     Kipini  -2.5257  26.22        81      98   8.15
# 20                       Jalu  29.0331  18.16        33       0   4.50
# 21                 Storm Lake  42.6411   1.19       100       1   3.60
# 22                     Labuan   5.2767  25.00        94      20   1.43
#
#          lon  temp_max
# 0    -9.5000     20.37
# 1   -42.0278     31.00
# 2   -69.2181     13.00
# 3   158.6483     -3.00
# 4  -114.3525    -31.67
# 5  -139.0333     25.85
# 6   -69.3632    -13.99
# 7   125.8000    -29.55
# 8  -175.2000     25.00
# 9    76.7067     30.00
# 10  -28.7000     13.00
# 11 -114.0611     18.61
# 12   -1.7957     12.22
# 13   30.7861    -12.78
# 14  147.3294     10.00
# 15  100.3354     29.00
# 16  -73.6500     16.40
# 17   -2.3560     15.00
# 18 -155.0900     19.00
# 19   40.5262     26.22
# 20   21.5482     18.16
# 21  -95.2097      2.22
# 22  115.2417     25.00

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Cities: Tiznit Province, Petropavlovsk-Kamchatskiy. Yellowknife, Qaanaaq, Magdagachi, Varkala, Ribeira Grande, Guerrero Negro, Salisbury’ Nikolskoye, George Town, Aras, Hilo, Jalu, Storm Lake, Labuan
#Lat: 29.5833, 53.0452, 62.456, 77.484, 53.45, 8.7341, 38.5167, 27.9769, 51.0693, 59.7035, 5.4112, 42.5617, 19.7297, 29.0331, 42.6411, 5.2767
#Humidity: 67, 80, 69, 73, ,80, 62, 65, 42, 100, 65, 58, 93, 69, 90, 93, 74
##Clouds: 0, 75, 75, 68, 32, 20, 99, 98, 90, 90, 20, 90, 75, 0, 20, 20
#Speed: 0.2, 2, 1.72, 2.78, 3.15, 2.55, 11.79, 1.76, 2.06, 7, 3.6, 1.03, 3.09, 3.75, 6.17, 1.03
#temp_max: 10.96, -2, -27, -16.35, -20.63, 31, 13.79, 17.87, 6.11, -17.78, 31, 5, 24, 9.97, 5.56, 28

# %%
import pandas as pd
North_data = { 'cities': ['Tiznit Province', 'Petropavlovsk_Kamchatskiy', 'Yellowknife', 'Qaanaaq', 'Magdagachi', 'Varkala', 'Ribeira Grande', 'Guerrero Negro', 'Salisbury', 'Nikolskoye', 'George Town', 'Aras', 'Hilo', 'Jalu', 'Storm Lake', 'Labuan'],
        'lat': [29.5833, 53.0452, 62.4560, 77.4840, 53.4500, 8.7341, 38.5167, 27.9769, 51.0693, 59.7035, 5.4112, 42.5617, 19.7297, 29.0331, 42.6411, 5.2767],
        'temp_max': [10.96, -2, -27, -16.35, -20.63, 31, 13.79, 17.87, 6.11, -17.78, 31, 5, 24, 9.97, 5.56, 28],
        'humidity':[67, 80, 69, 73, 80, 62, 65, 42, 100, 65, 58, 93, 69, 90, 93, 74],
        'clouds': [0, 75, 75, 68, 32, 20, 99, 98, 90, 90, 20, 90, 75, 0, 20, 20],
        'speed': [0.2, 2, 1.72, 2.78, 3.15, 2.55, 11.79, 1.76, 2.06, 7, 3.6, 1.03, 3.09, 3.75, 6.17, 1.03]
        }

North_data = pd.DataFrame(North_data, columns = ["cities", "lat","temp_max", "humidity", "clouds", "speed"])
print (North_data)
# Out:
#                        cities      lat  temp_max  humidity  clouds  speed
# 0             Tiznit Province  29.5833     10.96        67       0   0.20
# 1   Petropavlovsk_Kamchatskiy  53.0452     -2.00        80      75   2.00
# 2                 Yellowknife  62.4560    -27.00        69      75   1.72
# 3                     Qaanaaq  77.4840    -16.35        73      68   2.78
# 4                  Magdagachi  53.4500    -20.63        80      32   3.15
# 5                     Varkala   8.7341     31.00        62      20   2.55
# 6              Ribeira Grande  38.5167     13.79        65      99  11.79
# 7              Guerrero Negro  27.9769     17.87        42      98   1.76
# 8                   Salisbury  51.0693      6.11       100      90   2.06
# 9                  Nikolskoye  59.7035    -17.78        65      90   7.00
# 10                George Town   5.4112     31.00        58      20   3.60
# 11                       Aras  42.5617      5.00        93      90   1.03
# 12                       Hilo  19.7297     24.00        69      75   3.09
# 13                       Jalu  29.0331      9.97        90       0   3.75
# 14                 Storm Lake  42.6411      5.56        93      20   6.17
# 15                     Labuan   5.2767     28.00        74      20   1.03

# %%
 # Identify incomplete rows
North_data.dtypes
# Out:
# cities       object
# lat         float64
# temp_max    float64
# humidity      int64
# clouds        int64
# speed       float64
# dtype: object

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot out maximum temperature versus latitude of country
x_values = North_data['lat']
y_values = North_data['temp_max']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Maximum temperature')
plt.show()
plt.savefig("foo.png", bbox_inches='tight')

# %%
# Add the linear regression equation and line to plot
x_values = North_data['lat']
y_values = North_data['temp_max']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)} x + {round(intercept,2)}"

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g-")

plt.annotate(line_eq,(6,10), fontsize=20, color="orange")

plt.xlabel('Latitude of country')
plt.ylabel('Maximum temperature')
plt.show()
plt.savefig("foo.png", bbox_inches='tight')

# %%
#City: Arraial do Cabo, Río Gallegos, Atuona, Vaini, Hobart, Lebu, Kipini
#Lat: -23, -51.6, -9.8, -21.2, -42.9, -37.6, -2.53
#temp_max: 24, 8, 26.19, 29, 18.89, 13.07, 24.15
#humidity: 94, 61, 79, 70, 44, 79, 91
#clouds: 75, 20, 53, 20, 75, 0, 100
#wind_speed: 1.03, 10.29, 6.77, 3.6, 3.6, 8.03, 2.75

# %%
# DataFrame of Cities in Southern hemisphere using a dictionary of lists
import pandas as pd
south_data = {'cities': ['Arraial do Cabo', 'Río Gallegos', 'Atuona', 'Vaini', 'Hobart', 'Lebu', 'Kipini'],
    'Lat': [-23, -51.6, -9.8, -21.2, -42.9, -37.6, -2.53],
    'temp_max': [24, 8, 26.19, 29, 18.89, 13.07, 24.15],
    'humidity':[94, 61, 79, 70, 44, 79, 91],
    'clouds': [75, 20, 53, 20, 75, 0, 100],
    'wind_speed': [1.03, 10.29, 6.77, 3.6, 3.6, 8.03, 2.75]
    } 

south_data = pd.DataFrame(south_data, columns = ['cities', 'Lat','temp_max', 'humidity', 'clouds', 'wind_speed'])
print (south_data)
# Out:
#             cities    Lat  temp_max  humidity  clouds  wind_speed
# 0  Arraial do Cabo -23.00     24.00        94      75        1.03
# 1     Río Gallegos -51.60      8.00        61      20       10.29
# 2           Atuona  -9.80     26.19        79      53        6.77
# 3            Vaini -21.20     29.00        70      20        3.60
# 4           Hobart -42.90     18.89        44      75        3.60
# 5             Lebu -37.60     13.07        79       0        8.03
# 6           Kipini  -2.53     24.15        91     100        2.75

# %%
south_data.dtypes
# Out:
# cities         object
# Lat           float64
# temp_max      float64
# humidity        int64
# clouds          int64
# wind_speed    float64
# dtype: object

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# linear regression equation and line plot of North Hem humidity vs latitude
x_values = North_data['lat']
y_values = North_data['humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)} x + {round(intercept,2)}"

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g-")

plt.annotate(line_eq,(6,10), fontsize=20, color="orange")

plt.xlabel('Latitude of country')
plt.ylabel('Humidity')
plt.show()
plt.savefig("foo.png", bbox_inches='tight')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# linear regression equation and line plot of North Hem humidity vs latitude
x_values = south_data['Lat']
y_values = south_data['humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)} x + {round(intercept,2)}"

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g-")

plt.annotate(line_eq,(6,10), fontsize=20, color="orange")

plt.xlabel('Latitude of country')
plt.ylabel('Humidity')
plt.show()
plt.savefig("foo.png", bbox_inches='tight')

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# linear regression equation and line plot of North Hem humidity vs latitude
x_values = North_data['lat']
y_values = North_data['clouds']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)} x + {round(intercept,2)}"

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g-")

plt.annotate(line_eq,(6,10), fontsize=20, color="orange")

plt.xlabel('Latitude of country')
plt.ylabel('clouds')
plt.show()
plt.savefig("foo.png", bbox_inches='tight')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# linear regression equation and line plot of North Hem cloudiness vs latitude
x_values = North_data['lat']
y_values = North_data['clouds']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)} x + {round(intercept,2)}"

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g-")

plt.annotate(line_eq,(6,10), fontsize=20, color="orange")

plt.xlabel('Latitude of country')
plt.ylabel('Cloudiness')
plt.show()
plt.savefig("foo.png", bbox_inches='tight')

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# linear regression equation and line plot of North Hem wind speed vs latitude
x_values = North_data['lat']
y_values = North_data['speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)} x + {round(intercept,2)}"

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g-")

plt.annotate(line_eq,(6,10), fontsize=20, color="orange")

plt.xlabel('Latitude of country')
plt.ylabel('Wind speed')
plt.show()
plt.savefig("foo.png", bbox_inches='tight')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# linear regression equation and line plot of South Hem wind speed vs latitude
x_values = south_data['Lat']
y_values = south_data['wind_speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = f"y = {round(slope,2)} x + {round(intercept,2)}"

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g-")

plt.annotate(line_eq,(6,10), fontsize=20, color="orange")

plt.xlabel('Latitude of country')
plt.ylabel('Wind speed')
plt.show()
plt.savefig("foo.png", bbox_inches='tight')
